# %% [markdown]
# # Training an MNIST model with Pytorch

# %%
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ### Download training data

# %%
use_fashion_mnist = False
if use_fashion_mnist:
    training_data = datasets.FashionMNIST(
        root="data",
        train=True,
        download=True,
        transform=ToTensor()
    )
    test_data = datasets.FashionMNIST(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )
else:
    training_data = datasets.MNIST(
        root="data",
        train=True,
        download=True,
        transform=ToTensor()
    )
    test_data= datasets.MNIST(
        root="data",
        train=False,
        download=True,
        transform=ToTensor()
    )

# %% [markdown]
# ### Divide in batches

# %%
batch_size = 64

train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, c, H, W] {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, c, H, W] torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# ### Visualize the data

# %%
rows = 5
cols = 5
samples_to_visualize = rows * cols

fig, axes = plt.subplots(rows, cols, figsize=(12,8))
fig.suptitle("MNIST Samples", fontsize=16)

for i in range(samples_to_visualize):
    row = i //cols
    col = i % cols

    image, label = training_data[i]
    class_name = training_data.classes[label]

    axes[row, col].imshow(image.squeeze(), cmap="gray")
    axes[row, col].axis("off")
    axes[row, col].set_title(class_name, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Acceleration available?

# %%
device = (
    torch.accelerator.current_accelerator().type
    if torch.accelerator.is_available()
    else "gpu"
)
print(f"using {device} device")
# Out:
# using mps device

# %% [markdown]
# ### Define the model

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28,512),
            nn.ReLU(),
            nn.Linear(512,512),
            nn.ReLU(),
            nn.Linear(512,10)
        )
    
    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits
    
model = NeuralNetwork().to(device)

# %% [markdown]
# ### Optimizer and loss function

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %% [markdown]
# ### Training

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X,y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        pred = model(X)
        loss = loss_fn(pred, y)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(
        f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg test loss: {test_loss:>8f} \n"
    )

# %%
epochs = 10

for t in range(epochs):
    print(f"Epoch {t+1}\n------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
# Out:
# Epoch 1
# ------------------
# loss: 0.728277  [   64/60000]
# loss: 0.601314  [ 6464/60000]
# loss: 0.670449  [12864/60000]
# loss: 0.603314  [19264/60000]
# loss: 0.611318  [25664/60000]
# loss: 0.584323  [32064/60000]
# loss: 0.527467  [38464/60000]
# loss: 0.723806  [44864/60000]
# loss: 0.618723  [51264/60000]
# loss: 0.631000  [57664/60000]
# Test Error:
#  Accuracy: 85.6%, Avg test loss: 0.583699
#
# Epoch 2
# ------------------
# loss: 0.667711  [   64/60000]
# loss: 0.541481  [ 6464/60000]
# loss: 0.605691  [12864/60000]
# loss: 0.558090  [19264/60000]
# loss: 0.555594  [25664/60000]
# loss: 0.537671  [32064/60000]
# loss: 0.473381  [38464/60000]
# loss: 0.673027  [44864/60000]
# loss: 0.572290  [51264/60000]
# loss: 0.596685  [57664/60000]
# Test Error:
#  Accuracy: 86.5%, Avg test loss: 0.538976
#
# Epoch 3
# ------------------
# loss: 0.619445  [   64/60000]
# loss: 0.494559  [ 6464/60000]
# loss: 0.555351  [12864/60000]
# loss: 0.524186  [19264/60000]
# loss: 0.511865  [25664/60000]
# loss: 0.503975  [32064/60000]
# loss: 0.431312  [38464/60000]
# loss: 0.634589  [44864/60000]
# loss: 0.536083  [51264/60000]
# loss: 0.571465  [57664/60000]
# Test Error:
#  Accuracy: 87.1%, Avg test loss: 0.503987
#
# Epoch 4
# ------------------
# loss: 0.580022  [   64/60000]
# loss: 0.457190  [ 6464/60000]
# loss: 0.515171  [12864/60000]
# loss: 0.498183  [19264/60000]
# loss: 0.476838  [25664/60000]
# loss: 0.479013  [32064/60000]
# loss: 0.398086  [38464/60000]
# loss: 0.604693  [44864/60000]
# loss: 0.507398  [51264/60000]
# loss: 0.552563  [57664/60000]
# Test Error:
#  Accuracy: 87.7%, Avg test loss: 0.476016
#
# Epoch 5
# ------------------
# loss: 0.547049  [   64/60000]
# loss: 0.427121  [ 6464/60000]
# loss: 0.482302  [12864/60000]
# loss: 0.477719  [19264/60000]
# loss: 0.448242  [25664/60000]
# loss: 0.460017  [32064/60000]
# loss: 0.371419  [38464/60000]
# loss: 0.580834  [44864/60000]
# loss: 0.484324  [51264/60000]
# loss: 0.538042  [57664/60000]
# Test Error:
#  Accuracy: 88.1%, Avg test loss: 0.453236
#
# Epoch 6
# ------------------
# loss: 0.518893  [   64/60000]
# loss: 0.402743  [ 6464/60000]
# loss: 0.454807  [12864/60000]
# loss: 0.461300  [19264/60000]
# loss: 0.424490  [25664/60000]
# loss: 0.445143  [32064/60000]
# loss: 0.349651  [38464/60000]
# loss: 0.561286  [44864/60000]
# loss: 0.465507  [51264/60000]
# loss: 0.526532  [57664/60000]
# Test Error:
#  Accuracy: 88.5%, Avg test loss: 0.434383
#
# Epoch 7
# ------------------
# loss: 0.494535  [   64/60000]
# loss: 0.382817  [ 6464/60000]
# loss: 0.431394  [12864/60000]
# loss: 0.447844  [19264/60000]
# loss: 0.404450  [25664/60000]
# loss: 0.433178  [32064/60000]
# loss: 0.331619  [38464/60000]
# loss: 0.544897  [44864/60000]
# loss: 0.449895  [51264/60000]
# loss: 0.517188  [57664/60000]
# Test Error:
#  Accuracy: 88.7%, Avg test loss: 0.418567
#
# Epoch 8
# ------------------
# loss: 0.473220  [   64/60000]
# loss: 0.366407  [ 6464/60000]
# loss: 0.411088  [12864/60000]
# loss: 0.436680  [19264/60000]
# loss: 0.387327  [25664/60000]
# loss: 0.423258  [32064/60000]
# loss: 0.316434  [38464/60000]
# loss: 0.530933  [44864/60000]
# loss: 0.436715  [51264/60000]
# loss: 0.509295  [57664/60000]
# Test Error:
#  Accuracy: 89.0%, Avg test loss: 0.405124
#
# Epoch 9
# ------------------
# loss: 0.454322  [   64/60000]
# loss: 0.352791  [ 6464/60000]
# loss: 0.393209  [12864/60000]
# loss: 0.427225  [19264/60000]
# loss: 0.372529  [25664/60000]
# loss: 0.414843  [32064/60000]
# loss: 0.303499  [38464/60000]
# loss: 0.518864  [44864/60000]
# loss: 0.425408  [51264/60000]
# loss: 0.502543  [57664/60000]
# Test Error:
#  Accuracy: 89.2%, Avg test loss: 0.393567
#
# Epoch 10
# ------------------
# loss: 0.437427  [   64/60000]
# loss: 0.341387  [ 6464/60000]
# loss: 0.377259  [12864/60000]
# loss: 0.419117  [19264/60000]
# loss: 0.359704  [25664/60000]
# loss: 0.407532  [32064/60000]
# loss: 0.292344  [38464/60000]
# loss: 0.508281  [44864/60000]
# loss: 0.415551  [51264/60000]
# loss: 0.496676  [57664/60000]
# Test Error:
#  Accuracy: 89.4%, Avg test loss: 0.383515

# %% [markdown]
# ### Save model

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved pytorch model to model.pth")
# Out:
# Saved pytorch model to model.pth

# %% [markdown]
# ### Load model

# %%
model = NeuralNetwork().to(device)
model.load_state_dict(torch.load("model.pth", weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Inference

# %%
import random

classes = test_data.classes
def visualize_sample(image, actual_label, predicted_label):
    plt.figure(figsize=(2, 2))
    plt.imshow(image.squeeze(), cmap="gray")
    plt.title(f"Actual: {actual_label}, Predicted: {predicted_label}")
    plt.axis("off")
    plt.show()


model.eval()

random_index = random.randint(0, len(test_data))
x, y = test_data[random_index][0], test_data[random_index][1]
with torch.no_grad():
    x = x.to(device)
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    visualize_sample(x.cpu(), actual, predicted)
    print(f'Actual: "{actual}", Predicted: "{predicted}"')
